# %%
# КОД ОБУЧЕНИЯ МОДЕЛИ
from catboost import CatBoostRegressor
from sklearn.model_selection import TimeSeriesSplit

# Обучение модели для прогноза срока
model_duration = CatBoostRegressor(
    iterations=1500,
    learning_rate=0.03,
    depth=6,
    l2_leaf_reg=3.5,
    early_stopping_rounds=50,
    verbose=0
)
model_duration.fit(
    X_train, 
    y_duration_train,
    eval_set=(X_test, y_duration_test),
    use_best_model=True
)

# Обучение модели для прогноза стоимости
model_cost = CatBoostRegressor(
    iterations=1500,
    learning_rate=0.03,
    depth=6,
    l2_leaf_reg=3.5,
    early_stopping_rounds=50,
    verbose=0
)
model_cost.fit(
    X_train, 
    y_cost_train,
    eval_set=(X_test, y_cost_test),
    use_best_model=True
)

# %%
# КОД SHAP-АНАЛИЗА
import shap

def explain_prediction(model, X_sample):
    """Объяснение прогноза с помощью SHAP"""
    explainer = shap.TreeExplainer(model)
    shap_values = explainer.shap_values(X_sample)
    return shap_values

# Пример использования
shap_values = explain_prediction(model_duration, X_sample)
